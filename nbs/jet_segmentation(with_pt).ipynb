# %%
# imports
import numpy as np
import pandas as pd
import torch
from torch_geometric.data import Data, DataLoader
from torch_geometric.utils import dense_to_sparse
from torch_geometric.utils import to_networkx
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
import torch_geometric
import networkx as nx
from torch_geometric.nn import global_mean_pool
plt.style.use("dark_paper")
def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(out.detach().cpu().numpy())

    fig,ax = plt.subplots(1,1,figsize=(10,10))
    plt.xticks([])
    plt.yticks([])
    plt.scatter(z[:, 0], z[:, 1], s=70, c=color,cmap="Dark2")
    return fig,ax
def plot_graph(h, color, epoch=None, loss=None):
    fig,ax = plt.subplots(1,1,figsize=(7,7))
    plt.xticks([])
    plt.yticks([])

    if torch.is_tensor(h):
        h = h.detach().cpu().numpy()
        plt.scatter(h[:, 0], h[:, 1], s=140, c=color, cmap="Set2")
        if epoch is not None and loss is not None:
            plt.xlabel(f'Epoch: {epoch}, Loss: {loss.item():.4f}', fontsize=16)
    else:
        nx.draw_networkx(G, pos=nx.spring_layout(G, seed=42), with_labels=False,
                         node_color=color,edge_color="w", cmap="Set2")
    return fig,ax
from torch_geometric.utils import to_dense_adj

# %%
def getDR(tensor):
    phi = tensor[:,-3].repeat_interleave(len(tensor)).view(len(tensor),-1)
    phi -= tensor[:,-3]
    eta = tensor[:,-2].repeat_interleave(len(tensor)).view(len(tensor),-1)
    eta -= tensor[:,-2]
    return torch.sqrt(eta**2+phi**2)

# %%
def _process(data): 
    x=data.loc[:,["E","px","py","pz","eta","phi","pT"]].to_numpy()
    x=torch.from_numpy(x).float()
    try:
        y=data.loc[:,["mask"]].to_numpy()
    except KeyError:
        y=np.zeros((len(x),1))
    #edge_index=dense_to_sparse(torch.ones(x.shape[0],x.shape[0]).fill_diagonal_(0))[0]#complete
    #edge_index=dense_to_sparse(torch.eye(x.shape[0]))[0]#self only
    #edge_index=dense_to_sparse(torch.ones(x.shape[0],x.shape[0]))[0]#complete graph
    distances = getDR(x)
    edge_index=torch_geometric.nn.radius_graph(distances,r=1)#GCNConv adds self loops
    w = 1/(1+distances[edge_index[0],edge_index[1]])
    data = Data(x=x,
        y=torch.from_numpy(y).float(),
        edge_index=edge_index, 
        edge_weight = w
        ) 
    data.z = (data.y==1).any().float().view(1,1)
    return data

# %%
# train_set = [_process(pd.read_hdf("data/W/evts.h5", key=f"evt{i}")) for i in range(1,2000)] +\
#             [_process(pd.read_hdf("data/QCD/evts_qcd.h5", key=f"evt{i}")) for i in range(1,2000)]
# val_set = [_process(pd.read_hdf("data/W/evts.h5", key=f"evt{i}")) for i in range(2000,2201)]+\
#                      [_process(pd.read_hdf("data/QCD/evts_qcd.h5", key=f"evt{i}")) for i in range(2000,2201)]
train_set = [_process(pd.read_hdf("data/W/full_evts_300pT.h5", key=f"evt{i}")) for i in range(1,150)]
val_set = [_process(pd.read_hdf("data/W/full_evts_300pT.h5", key=f"evt{i}")) for i in range(150,300)]

# %%
train_loader = DataLoader(train_set, batch_size=1,shuffle=False)
val_loader = DataLoader(val_set, batch_size=1,shuffle=False)

# %%
data = train_set[1]  # Get the first graph object.

print()
print(data)
print('=============================================================')

# Gather some statistics about the first graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Contains isolated nodes: {data.contains_isolated_nodes()}')
print(f'Contains self-loops: {data.contains_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')
# Out:
# Data(edge_index=[2, 508], edge_weight=[508], x=[303, 7], y=[303, 1], z=[1, 1])
# =============================================================
# Number of nodes: 303
# Number of edges: 508
# Average node degree: 1.68
# Contains isolated nodes: True
# Contains self-loops: False
# Is undirected: True

# %%
events = [pd.read_hdf("data/W/full_evts_300pT.h5", key=f"evt{i}") for i in range(1,5)]

# %%
# Plot
i = 0
from_parton = events[i][events[i]["mask"]==1]
notfrom_parton = events[i][events[i]["mask"]==0]

s=300
fig, (ax,ax1) = plt.subplots(1, 2, dpi=120,figsize=(10,5),sharey=True)
ax.scatter(from_parton.theta, from_parton.phi, label="W Jet",s=s*from_parton.pT/events[i].pT.max(),alpha=.9)
ax.scatter(notfrom_parton.theta.values[1:], notfrom_parton.phi.values[1:], 
           label="other",s=s*notfrom_parton.pT[1:]/events[i].pT.max(),alpha=.5)


ax.set_xlabel(r"$\theta$")
ax.set_ylabel(r"$\phi$")

ax1.scatter(from_parton.eta, from_parton.phi, label="W Jet",s=s*from_parton.pT/events[i].pT.max(),
            alpha=.9)
ax1.scatter(notfrom_parton.eta.values[1:], notfrom_parton.phi.values[1:], label="other",
            s=s*notfrom_parton.pT[1:]/events[i].pT.max(),alpha=.5)
ax1.set_xlabel(r"$\eta$")

fig.suptitle("Final State Particles")
fig.tight_layout(w_pad=0)
plt.legend(loc=(1, .8))
plt.show()

# %%
class GCN_static(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        torch.manual_seed(12345)
        #GraphConv vs GCNConv
        self.conv1 = torch_geometric.nn.GraphConv(4, hidden_channels)
        self.conv2 = torch_geometric.nn.GraphConv(hidden_channels, hidden_channels)
        self.conv3 = torch_geometric.nn.GraphConv(hidden_channels, hidden_channels)
        self.conv4 = torch_geometric.nn.GraphConv(hidden_channels, hidden_channels)
        self.conv5 = torch_geometric.nn.GraphConv(hidden_channels, 1)
        self.batchnorm = torch.nn.BatchNorm1d(hidden_channels)
    def forward(self, x, edge_index,edge_weight=None,batch=None):
        x = self.conv1(x, edge_index,edge_weight=edge_weight).relu()
        x = self.batchnorm(x)
        x = self.conv2(x, edge_index,edge_weight=edge_weight).relu()
        x = self.conv3(x, edge_index,edge_weight=edge_weight).relu()
        x = self.conv4(x, edge_index,edge_weight=edge_weight).relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv5(x, edge_index,edge_weight=edge_weight)
        return x

# %%
class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
#         self.conv1 = torch_geometric.nn.GCNConv(4, hidden_channels)
#         self.conv2 = torch_geometric.nn.GCNConv(hidden_channels, hidden_channels)
#         self.conv3 = torch_geometric.nn.GCNConv(hidden_channels, 1)
        self.mlp1 = torch.nn.Sequential(torch.nn.Linear(4*2,hidden_channels))
        self.mlp2 = torch.nn.Sequential(torch.nn.Linear(hidden_channels*2,hidden_channels))
        self.mlp3 = torch.nn.Sequential(torch.nn.Linear(hidden_channels*2,hidden_channels))
        self.mlp4 = torch.nn.Sequential(torch.nn.Linear(hidden_channels*2,hidden_channels))        
        self.mlp5 = torch.nn.Sequential(torch.nn.Linear(hidden_channels*2,1))
        self.conv1 = torch_geometric.nn.DynamicEdgeConv(self.mlp1,k=15,aggr="max")
        self.conv2 = torch_geometric.nn.DynamicEdgeConv(self.mlp2,k=5,aggr="max")
        self.conv3 = torch_geometric.nn.DynamicEdgeConv(self.mlp3,k=5,aggr="max")
        self.conv4 = torch_geometric.nn.DynamicEdgeConv(self.mlp4,k=5,aggr="max")
        self.conv5 = torch_geometric.nn.DynamicEdgeConv(self.mlp5,k=5,aggr="max")
        self.mlp = torch.nn.Sequential(torch.nn.Linear(hidden_channels,hidden_channels),
                                        torch.nn.Linear(hidden_channels,1))
        self.batchnorm = torch.nn.BatchNorm1d(hidden_channels)
    def forward(self, x, edge_index,batch):
#         x = self.conv1(x, edge_index).relu()
#         #x = self.batchnorm(x)
#         x = self.conv2(x, edge_index).relu()
#         #x = F.dropout(x, p=0.5, training=self.training)
#         x = self.conv3(x, edge_index)
        x = self.conv1(x).relu()
        x = self.conv2(x).relu()
        y = global_mean_pool(x,batch)
        y = torch.nn.functional.dropout(y, p=0.5, training=self.training)
        y = self.mlp(y)
        x = self.conv3(x).relu()
        x = self.conv4(x).relu()
        x = self.conv5(x)
        return (x,y)

# %%
from torch.nn import functional as F
class GCN_dynamic(torch.nn.Module):
    def __init__(self, hidden_channels,depth = 3):
        super().__init__()
        torch.manual_seed(12345)
        self.depth = depth
        self.mlp_in = torch.nn.Sequential(torch.nn.Linear(4*2,hidden_channels),torch.nn.ReLU(),
                                        torch.nn.Linear(hidden_channels,hidden_channels),torch.nn.ReLU(),
                                        torch.nn.Linear(hidden_channels,hidden_channels),torch.nn.ReLU(),
                                       )
        self.conv_in = torch_geometric.nn.DynamicEdgeConv(self.mlp_in,k=15,aggr="max")
        self.conv_layers = torch.nn.ModuleList()
        for i in range(depth):
            mlp = torch.nn.Sequential(torch.nn.Linear(hidden_channels*2,hidden_channels))
            self.conv_layers.append(torch_geometric.nn.DynamicEdgeConv(mlp,k=5,aggr="max"))
        self.mlp_out = torch.nn.Sequential(torch.nn.Linear(hidden_channels*2,1))
        self.conv_out = torch_geometric.nn.DynamicEdgeConv(self.mlp_out,k=5,aggr="max")
        self.batchnorm = torch.nn.BatchNorm1d(hidden_channels)
    def forward(self, x, edge_index,batch):
        x = self.conv_in(x).relu()
#         x = self.batchnorm(x)
#         x = self.conv2(x).relu()
#         x = self.conv3(x).relu()
#         x = self.conv4(x).relu()
        for i in range(self.depth-1):
            x = self.conv_layers[i](x).relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv_out(x)
        return x

# %% [markdown]
# # Complete graph

# %%
targets = torch.from_numpy(np.concatenate([data.y.tolist() for data in train_set]))
ones_weight = targets.sum().item()/len(targets)
weight = 1/torch.tensor([1-ones_weight,ones_weight])/2

# %%
def get_weights(targets):
    weight_ = weight[targets.data.view(-1).long()].view_as(targets)
    weight_ = weight_.to(targets.device)
    return weight_
    
def train(data,weighted=True):
    gcn.train()
    weight_ = get_weights(data.y)
    segmentation = gcn(data.x[:,[0,-3,-2,-1]],data.edge_index,data.edge_weight,None)
                       #,data.edge_weight,data.batch)
    #segmentation = gcn(data.x[:,[0,1,2,3]],data.edge_index,data.batch)
    segmentation = torch.sigmoid(segmentation)
    loss = criterion(segmentation, data.y)
    if weighted:
        loss = (loss*weight_).mean()
    else:
        loss = loss.mean() #mean over graph and batch
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    return loss.item()

def val(data,weighted=True):
    gcn.eval()
    weight_ = get_weights(data.y)
    with torch.no_grad():
        segmentation = gcn(data.x[:,[0,-3,-2,-1]],data.edge_index,data.edge_weight,None)#[data.train_mask]
        segmentation = torch.sigmoid(segmentation)
        loss = criterion(segmentation,data.y)
        if weighted:
            loss = (loss*weight_).mean()
        else:
            loss = loss.mean()
    return loss.item()

# %%
#single graph
device = 'cuda:0'
gcn = GCN_static(128)
gcn.to(device)
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(gcn.parameters(),weight_decay=5e-4,lr=5e-3)
epochs = 500
data = next(iter(train_loader))
data = data.to(device)
for epoch in range(1,epochs):
    loss = train(data)
    if epoch%50==1:
        print(f"Epoch {epoch:^3d}/{epochs} | Loss segmentation {loss:^4.4f}")#| Loss class {loss[1]:^4.4f}")
# Out:
# Epoch  1 /500 | Loss segmentation 0.2402
# Epoch 51 /500 | Loss segmentation 0.0533
# Epoch 101/500 | Loss segmentation 0.0289
# Epoch 151/500 | Loss segmentation 0.0248
# Epoch 201/500 | Loss segmentation 0.0246
# Epoch 251/500 | Loss segmentation 0.0246
# Epoch 301/500 | Loss segmentation 0.0027
# Epoch 351/500 | Loss segmentation 0.0023
# Epoch 401/500 | Loss segmentation 0.0024
# Epoch 451/500 | Loss segmentation 0.0025

# %%
pred = (torch.sigmoid(gcn(data.x[:,[0,-3,-2,-1]].to(device),data.edge_index.to(device), None,
                          torch.zeros(len(data.x)).to(device).long())).detach().cpu().flatten().numpy()>.5).astype(int)
target = data.y.flatten().cpu().numpy()
print(classification_report(target,pred))
print(confusion_matrix(target,pred,))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       530
#          1.0       1.00      0.97      0.99        34
#
#     accuracy                           1.00       564
#    macro avg       1.00      0.99      0.99       564
# weighted avg       1.00      1.00      1.00       564
#
# [[530   0]
#  [  1  33]]

# %%
#all graphs
device = 'cuda:0'
gcn = GCN_static(256)
gcn.to(device)
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(gcn.parameters(),weight_decay=5e-4,lr=1e-5)
epochs = 200
losses_train = list()
losses_val = list()
for epoch in range(1,epochs):
    loss_train = 0
    for dat in train_loader:
        loss = train(dat.to(device))
        losses_train.append(loss)
        loss_train +=loss
    loss_train/=len(train_loader)
    if epoch%2==0:
        loss_val = 0
        for dat in val_loader:
            loss = val(dat.to(device))
            losses_val.append(loss)
            loss_val += loss
        loss_val/=len(val_loader)
        #print(f"Epoch {epoch:^3d}/{epochs} | Loss train {loss:^4.4f}")
        print(f"Epoch {epoch:^3d}/{epochs} | Loss train {loss_train:^4.4f}| Loss val {loss_val:^4.4f}")
# Out:
# Epoch  2 /200 | Loss train 0.2636| Loss val 0.2460
# Epoch  4 /200 | Loss train 0.1907| Loss val 0.1742
# Epoch  6 /200 | Loss train 0.1309| Loss val 0.1241
# Epoch  8 /200 | Loss train 0.1110| Loss val 0.1108
# Epoch 10 /200 | Loss train 0.1041| Loss val 0.1059
# Epoch 12 /200 | Loss train 0.1010| Loss val 0.1017
# Epoch 14 /200 | Loss train 0.0997| Loss val 0.1019
# Epoch 16 /200 | Loss train 0.0999| Loss val 0.1006
# Epoch 18 /200 | Loss train 0.1006| Loss val 0.1000
# Epoch 20 /200 | Loss train 0.0974| Loss val 0.1019
# Epoch 22 /200 | Loss train 0.0964| Loss val 0.0992
# Epoch 24 /200 | Loss train 0.0972| Loss val 0.1009
# Epoch 26 /200 | Loss train 0.0950| Loss val 0.0983
# Epoch 28 /200 | Loss train 0.0902| Loss val 0.0969
# Epoch 30 /200 | Loss train 0.0966| Loss val 0.1014
# Epoch 32 /200 | Loss train 0.0949| Loss val 0.0999
# Epoch 34 /200 | Loss train 0.0890| Loss val 0.1009
# Epoch 36 /200 | Loss train 0.0895| Loss val 0.1001
# Epoch 38 /200 | Loss train 0.0920| Loss val 0.1004
# Epoch 40 /200 | Loss train 0.0883| Loss val 0.0989
# Epoch 42 /200 | Loss train 0.0904| Loss val 0.1019
# Epoch 44 /200 | Loss train 0.0922| Loss val 0.0970
# Epoch 46 /200 | Loss train 0.0896| Loss val 0.0969
# Epoch 48 /200 | Loss train 0.0863| Loss val 0.0954
# Epoch 50 /200 | Loss train 0.0852| Loss val 0.0955
# Epoch 52 /200 | Loss train 0.0907| Loss val 0.0996
# Epoch 54 /200 | Loss train 0.0832| Loss val 0.0994
# Epoch 56 /200 | Loss train 0.0820| Loss val 0.0966
# Epoch 58 /200 | Loss train 0.0845| Loss val 0.0984
# Epoch 60 /200 | Loss train 0.0791| Loss val 0.0978
# Epoch 62 /200 | Loss train 0.0799| Loss val 0.0973
# Epoch 64 /200 | Loss train 0.0847| Loss val 0.0974
# Epoch 66 /200 | Loss train 0.0801| Loss val 0.0965
# Epoch 68 /200 | Loss train 0.0849| Loss val 0.1020
# Epoch 70 /200 | Loss train 0.0838| Loss val 0.0971
# Epoch 72 /200 | Loss train 0.0823| Loss val 0.1010
# Epoch 74 /200 | Loss train 0.0811| Loss val 0.0978
# Epoch 76 /200 | Loss train 0.0776| Loss val 0.0985
# Epoch 78 /200 | Loss train 0.0756| Loss val 0.0982
# Epoch 80 /200 | Loss train 0.0770| Loss val 0.0958
# Epoch 82 /200 | Loss train 0.0826| Loss val 0.0951
# Epoch 84 /200 | Loss train 0.0776| Loss val 0.0958
# Epoch 86 /200 | Loss train 0.0762| Loss val 0.0944
# Epoch 88 /200 | Loss train 0.0800| Loss val 0.0994
# Epoch 90 /200 | Loss train 0.0771| Loss val 0.0969
# Epoch 92 /200 | Loss train 0.0763| Loss val 0.0959
# Epoch 94 /200 | Loss train 0.0769| Loss val 0.0990
# Epoch 96 /200 | Loss train 0.0748| Loss val 0.0962
# Epoch 98 /200 | Loss train 0.0778| Loss val 0.0983
# Epoch 100/200 | Loss train 0.0757| Loss val 0.0978
# Epoch 102/200 | Loss train 0.0759| Loss val 0.0967
# Epoch 104/200 | Loss train 0.0814| Loss val 0.0960
# Epoch 106/200 | Loss train 0.0735| Loss val 0.0975
# Epoch 108/200 | Loss train 0.0716| Loss val 0.0971
# Epoch 110/200 | Loss train 0.0782| Loss val 0.0941
# Epoch 112/200 | Loss train 0.0741| Loss val 0.0956
# Epoch 114/200 | Loss train 0.0722| Loss val 0.0955
# Epoch 116/200 | Loss train 0.0690| Loss val 0.0970
# Epoch 118/200 | Loss train 0.0725| Loss val 0.0952
# Epoch 120/200 | Loss train 0.0696| Loss val 0.0934
# Epoch 122/200 | Loss train 0.0767| Loss val 0.0945
# Epoch 124/200 | Loss train 0.0717| Loss val 0.0952
# Epoch 126/200 | Loss train 0.0708| Loss val 0.0972
# Epoch 128/200 | Loss train 0.0685| Loss val 0.0952
# Epoch 130/200 | Loss train 0.0685| Loss val 0.0988
# Epoch 132/200 | Loss train 0.0773| Loss val 0.0984
# Epoch 134/200 | Loss train 0.0689| Loss val 0.0959
# Epoch 136/200 | Loss train 0.0687| Loss val 0.0968
# Epoch 138/200 | Loss train 0.0677| Loss val 0.0969
# Epoch 140/200 | Loss train 0.0713| Loss val 0.0962
# Epoch 142/200 | Loss train 0.0677| Loss val 0.0906
# Epoch 144/200 | Loss train 0.0699| Loss val 0.1006
# Epoch 146/200 | Loss train 0.0684| Loss val 0.0973
# Epoch 148/200 | Loss train 0.0685| Loss val 0.0956
# Epoch 150/200 | Loss train 0.0697| Loss val 0.0954
# Epoch 152/200 | Loss train 0.0681| Loss val 0.0972
# Epoch 154/200 | Loss train 0.0665| Loss val 0.0970
# Epoch 156/200 | Loss train 0.0673| Loss val 0.0962
# Epoch 158/200 | Loss train 0.0672| Loss val 0.0945
# Epoch 160/200 | Loss train 0.0655| Loss val 0.0971
# Epoch 162/200 | Loss train 0.0657| Loss val 0.0961
# Epoch 164/200 | Loss train 0.0693| Loss val 0.0951
# Epoch 166/200 | Loss train 0.0659| Loss val 0.0957
# Epoch 168/200 | Loss train 0.0687| Loss val 0.0988
# Epoch 170/200 | Loss train 0.0664| Loss val 0.0994
# Epoch 172/200 | Loss train 0.0654| Loss val 0.0982
# Epoch 174/200 | Loss train 0.0660| Loss val 0.0921
# Epoch 176/200 | Loss train 0.0642| Loss val 0.0934
# Epoch 178/200 | Loss train 0.0651| Loss val 0.0969
# Epoch 180/200 | Loss train 0.0660| Loss val 0.0919
# Epoch 182/200 | Loss train 0.0652| Loss val 0.0973
# Epoch 184/200 | Loss train 0.0690| Loss val 0.0948
# Epoch 186/200 | Loss train 0.0644| Loss val 0.0947
# Epoch 188/200 | Loss train 0.0655| Loss val 0.0951
# Epoch 190/200 | Loss train 0.0655| Loss val 0.0909
# Epoch 192/200 | Loss train 0.0639| Loss val 0.0971
# Epoch 194/200 | Loss train 0.0627| Loss val 0.0956
# Epoch 196/200 | Loss train 0.0628| Loss val 0.0927
# Epoch 198/200 | Loss train 0.0616| Loss val 0.0932

# %%
plt.plot(np.reshape(losses_train,(len(train_set),-1)).mean(1))
plt.plot(np.reshape(losses_val,(len(val_set),-1)).mean(1))

# %% [markdown]
# ### Metrics

# %%
pred = []
target = []
gcn.train()
for data in train_loader:
#data = next(iter(train_loader))
    data = data.to(device)
    pred += (torch.sigmoid(gcn(data.x[:,[0,-3,-2,-1]].to(device),data.edge_index.to(device), 
                              None)).detach().cpu().flatten()>.5).int().tolist()
    target += data.y.flatten().cpu().tolist()
print(classification_report(target,pred))
print(confusion_matrix(target,pred,))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.99      0.97     66478
#          1.0       0.85      0.38      0.52      5830
#
#     accuracy                           0.94     72308
#    macro avg       0.90      0.69      0.75     72308
# weighted avg       0.94      0.94      0.93     72308
#
# [[66080   398]
#  [ 3621  2209]]

# %%
pred = []
target = []
for data in val_loader:
#data = next(iter(train_loader))
    data = data.to(device)
    pred += (torch.sigmoid(gcn(data.x[:,[0,-3,-2,-1]].to(device),data.edge_index.to(device), 
                              None)).detach().cpu().flatten()>.5).int().tolist()
    target += data.y.flatten().cpu().tolist()
print(classification_report(target,pred))
print(confusion_matrix(target,pred,))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.98      0.96     69755
#          1.0       0.50      0.20      0.28      5859
#
#     accuracy                           0.92     75614
#    macro avg       0.72      0.59      0.62     75614
# weighted avg       0.90      0.92      0.91     75614
#
# [[68584  1171]
#  [ 4696  1163]]

# %% [markdown]
# # Plots

# %%
data = val_set[1]
data = data.to(device)
cut = .5
pred = (torch.sigmoid(gcn(data.x[:,[0,-3,-2,-1]].to(device),data.edge_index.to(device), 
                              None)).detach().cpu().flatten()>cut).int()
target = data.y.flatten().cpu().tolist()
data.to("cpu")
print(classification_report(target,pred.numpy()))
print(confusion_matrix(target,pred.numpy()))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.94       334
#          1.0       0.45      0.39      0.42        36
#
#     accuracy                           0.89       370
#    macro avg       0.69      0.67      0.68       370
# weighted avg       0.89      0.89      0.89       370
#
# [[317  17]
#  [ 22  14]]

# %%
# Plot
from_parton = data.x[pred==1].numpy()
notfrom_parton = data.x[pred==0].numpy()

from_parton_truth = data.x[data.y.flatten()==1].numpy()
notfrom_parton_truth = data.x[data.y.flatten()==0].numpy()

s=300
fig, (ax,ax1) = plt.subplots(1, 2, dpi=120,figsize=(10,5),sharey=True)
ax.scatter(from_parton_truth[:,-3], from_parton_truth[:,-2], label="W Jet",s=s*from_parton_truth[:,-1]/data.x[:,-1].max(),
           alpha=.9)
ax.scatter(notfrom_parton_truth[:,-3], notfrom_parton_truth[:,-2], 
           label="other",s=s*notfrom_parton_truth[:,-1]/data.x[:,-1].max(),
           alpha=.5)


ax.set_xlabel(r"$\eta$")
ax.set_ylabel(r"$\phi$")
ax.set_title("Truth")

ax1.scatter(from_parton[:,-3], from_parton[:,-2], label="W Jet",s=s*from_parton[:,-1]/data.x[:,-1].max(),
            alpha=.9)
ax1.scatter(notfrom_parton[:,-3], notfrom_parton[:,-2], label="other",
            s=s*notfrom_parton[:,-1]/data.x[:,-1].max(),
            alpha=.5)
ax1.set_xlabel(r"$\eta$")
ax1.set_title("Prediction")

fig.suptitle("Final State Particles")
fig.tight_layout(w_pad=0)
plt.legend(loc=(1, .8))
plt.show()
